# %%
import numpy as np
import scipy.io as sio
import pandas as pd
import matplotlib.pyplot as plt

# %%
## Load data
data = sio.loadmat('food_data.mat')
signal = data['datass']
signal = np.reshape(signal,(-1, 256))

values = data['output']
values = np.reshape(values,(-1,15))
values = values[:,10:14] # 10: Calorie value, 11: Carbohydrates, 12: Fat, 13: Proteins

# %%
plt.plot(signal[0,:])

# %%
plt.boxplot(values)
plt.show()
